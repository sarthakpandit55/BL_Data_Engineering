# %%
import pandas as pd

# %%
dara = pd.read_csv(r"retail_sales_dataset.csv")
dara
# Out:
#        transaction_id transaction_date customer_id customer_gender  \
# 0            T0000001       2024-04-24     C000820           Other
# 1            T0000002       2025-07-12     C002849           Other
# 2            T0000003       2025-06-01     C019727            Male
# 3            T0000004       2025-08-26     C009116            Male
# 4            T0000005       2024-12-10     C003350            Male
# ...               ...              ...         ...             ...
# 119995       T0119996       2025-05-17     C002626           Other
# 119996       T0119997       2025-11-16     C007741            Male
# 119997       T0119998       2025-07-18     C000588          Female
# 119998       T0119999       2025-07-27     C009032           Other
# 119999       T0120000       2025-01-27     C003307          Female
#
#        customer_age_group customer_segment product_id       product_name  \
# 0                   35-44        Returning      P1082          Dumbbells
# ...
